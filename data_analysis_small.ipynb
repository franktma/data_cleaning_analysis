# %%
# standing data tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
skim=pd.read_csv('data/2016_All_Contracts_Delta_20170715_skim.csv')
skim.fillna(value="", inplace=True)

# %%
skim.info(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15846 entries, 0 to 15845
# Data columns (total 9 columns):
# Unnamed: 0             15846 non-null int64
# vendorname             15846 non-null object
# vendoralternatename    15846 non-null object
# streetaddress          15846 non-null object
# city                   15846 non-null object
# state                  15846 non-null object
# zipcode                15846 non-null object
# phoneno                15846 non-null object
# registrationdate       15846 non-null object
# dtypes: int64(1), object(8)
# memory usage: 1.1+ MB

# %%
skim.head(10)
# Out:
#    Unnamed: 0                                    vendorname  \
# 0           0              BELL BOEING JOINT PROJECT OFFICE
# 1           1              BELL BOEING JOINT PROJECT OFFICE
# 2           2                  REINHART FOODSERVICE, L.L.C.
# 3           3                                ILLUMINA, INC.
# 4           4                              ICF INCORPORATED
# 5           5  PROFESSIONAL AND SCIENTIFIC ASSOCIATES, INC.
# 6           6                MCCREARY COUNTY WATER DISTRICT
# 7           7              BELL BOEING JOINT PROJECT OFFICE
# 8           8                    PTT PUBLIC COMPANY LIMITED
# 9           9                                 DAE SUNG, LLC
#
#   vendoralternatename                      streetaddress           city  \
# 0                               401 TILTROTOR DR PLANT A       AMARILLO
# 1                               401 TILTROTOR DR PLANT A       AMARILLO
# 2      SOUTHERN FOODS            117 MITCH MCCONNELL WAY  BOWLING GREEN
# ...

# %%
g0=skim.groupby('vendorname').count()

# %%
g0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2201 entries, 101MOBILITY, LLC to ZOOM INC.
# Data columns (total 8 columns):
# Unnamed: 0             2201 non-null int64
# vendoralternatename    2201 non-null int64
# streetaddress          2201 non-null int64
# city                   2201 non-null int64
# state                  2201 non-null int64
# zipcode                2201 non-null int64
# phoneno                2201 non-null int64
# registrationdate       2201 non-null int64
# dtypes: int64(8)
# memory usage: 154.8+ KB

# %%
g0.rename(columns={'Unnamed: 0':'vendorname_count'}, inplace=True)
g0.head(20)
# Out:
#                                              vendorname_count  \
# vendorname
# 101MOBILITY, LLC                                            1
# 2020 COMPANY, LLC                                           1
# 21 DELTA ENGINEERS, L.L.C.                                  2
# 22ND CENTURY TECHNOLOGIES INC.                              4
# 3 PHOENIX, INC.                                             2
# 3 R RESOURCES, INC.                                         1
# 3D ENVIROLOGICS LLC                                         1
# 3M COMPANY                                                  2
# 4 STAR TECHNOLOGIES, INC.                                   2
# 8660 OSHA, LLC                                              1
# A & F ENTERPRISES                                           1
# A & G PUMPING, INC                                          1
# A & T MARKETING INC.                                        1
# A'VIANDS, LLC                                               2
# ...

# %%
h0 = plt.hist(g0['vendorname_count'],300,(0,300))
plt.xscale('log')
plt.yscale('log')

# %%
g0['vendorname_count'].describe()
# Out:
# count    2201.000000
# mean        7.199455
# std        68.498552
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max      2930.000000
# Name: vendorname_count, dtype: float64

# %%
g0.sort(['vendorname_count'], ascending=[False])
# Out:
# /Users/hwu/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                     vendorname_count  \
# vendorname
# BELL BOEING JOINT PROJECT OFFICE                                2930
# REINHART FOODSERVICE, L.L.C.                                    1027
# FOUR POINTS TECHNOLOGY, L.L.C.                                   299
# HERMAN MILLER, INC                                               271
# PROJECT SUPPORT SERVICES, INC.                                   254
# PROFESSIONAL AND SCIENTIFIC ASSOCIATES, INC.                     232
# SCIENCE APPLICATIONS INTERNATIONAL CORPORATION                   207
# ALLEGHENY SCIENCE & TECHNOLOGY CORPORATION                       203
# BROOKFIELD RELOCATION INC                                        183
# ACCENTURE NATIONAL SECURITY SERVICES LIMITED LI...               157
# ...

# %%
import RecordCleaner
reload(RecordCleaner)
from RecordCleaner import rdcleaner

rc0 = rdcleaner(skim.head(1000),threshold=0.9)
rc0.group_sim()
rc0.summarize()
# Out:
# ** Cleaning Analysis Setup **
# Start with 1000 records
# similarity threshold = 0.90
# similarity mode = name
#
# ======== Cleaning Starts! =========
# Found similar - Close call!!! sim_score =  0.901960784314
# southernresearchinstitute ['SOUTHERN RESEARCH', '2000 9TH AVE S', 'BIRMINGHAM', 'AL', '2055812633', '06/26/2001']
# southwestresearchinstitute ['S W R I', '6220 CULEBRA RD', 'SAN ANTONIO', 'TX', '2105222122', '02/26/2002']
#
# Not similar - Close call!!! sim_score =  0.875
# arescorporation ['', '1440 CHAPIN AVE STE 390', 'BURLINGAME', 'CA', '', '']
# harriscorporation ['GOVERNMENT COMMUNICATIONS SYSTEMS DIVISION', '2400 PALM BAY RD NE', 'PALM BAY', 'FL', '3217297745', '11/05/2001']
#
# Not similar - Close call!!! sim_score =  0.871794871795
# torchtechnologiesinc ['', '4035 CHRIS DR SW STE C', 'HUNTSVILLE', 'AL', '2563196000', '10/28/2002']
# eoirtechnologiesinc ['', '6165 GUARDIAN GATEWAY STE J', 'ABERDEEN PROVING GROUND', 'MD', '4103068722', '10/02/2002']
#
# ...

# %%
# now with the full record
rc1 = rdcleaner(skim.head(1000),threshold=0.9,sim_mode='full_record')
rc1.group_sim()
rc1.summarize()
# Out:
# ** Cleaning Analysis Setup **
# Start with 1000 records
# similarity threshold = 0.90
# similarity mode = full_record
#
# ======== Cleaning Starts! =========
# Not similar - Close call!!! sim_score =  0.875
# arescorporation ['', '1440 CHAPIN AVE STE 390', 'BURLINGAME', 'CA', '', '']
# harriscorporation ['GOVERNMENT COMMUNICATIONS SYSTEMS DIVISION', '2400 PALM BAY RD NE', 'PALM BAY', 'FL', '3217297745', '11/05/2001']
#
# Not similar - Close call!!! sim_score =  0.866666666667
# icfincorporated ['', '9300 LEE HWY', 'FAIRFAX', 'VA', '', '']
# cxtincorporated ['', '2420 N SULLIVAN RD', 'SPOKANE', 'WA', '5099218766', '01/29/2002']
#
# # of raw vendors 367
# # of cleaned vendors 367
# cleaned away:
# set([])
